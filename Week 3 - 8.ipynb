# %%
import boto3
import pandas as pd
from trp import Document

bucketname = "kadakareer1"
tablename = "Annex-G_Psycho-Evaluation-Form 2.jpg"

module = boto3.client('textract')

response = module.analyze_document(
    Document={
        'S3Object': {
            'Bucket': bucketname,
            'Name': tablename
        }
    },
    FeatureTypes=["TABLES"]
)
doc = Document(response)

table_data = []

for page in doc.pages:
    for table in page.tables:
        for row in table.rows:
            row_data = []
            for cell in row.cells:
                row_data.append(cell.text)
            table_data.append(row_data)

df = pd.DataFrame(table_data)

print('-----Amazon Textract has detected as follows-----')
print(df)

df.to_csv('Week 3 - 8.csv', index=False)
# Out:
# -----Amazon Textract has detected as follows-----
#                                                     0                 1  \
# 0                                         MOTIVATION                 1
# 1                                      Assertiveness     NOT_SELECTED,
# 2                                       Independence     NOT_SELECTED,
# 3                                    Resourcefulness     NOT_SELECTED,
# 4
# 5              INTERPERSONAL AND PERSONAL ADJUSTMENT   NOT_SELECTED, 1
# 6   Relationship with Peers and Co-workers (Team m...    NOT_SELECTED,
# 7   Relationship with Superiors,Employers and Auth...    NOT_SELECTED,
# 8                                        Self-esteem     NOT_SELECTED,
# 9                              Aggressive Tendencies     NOT_SELECTED,
# 10
# 11                                 GOAL- ORIENTATION   NOT_SELECTED, 1
# 12  Directs one's effort towards clear cut objecti...    NOT_SELECTED,
#
#                    2                 3               4                 5  \
# 0                 2   NOT_SELECTED, 3               4                 5
# 1     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
# 2     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,         SELECTED,
# 3     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
# 4                                                         NOT_SELECTED,
# 5   NOT_SELECTED, 2   NOT_SELECTED, 3     SELECTED, 4   NOT_SELECTED, 5
# 6     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
# 7     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
# 8     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
# 9     NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,         SELECTED,
# 10                                                        NOT_SELECTED,
# 11  NOT_SELECTED, 2   NOT_SELECTED, 3     SELECTED, 4   NOT_SELECTED, 5
# 12    NOT_SELECTED,     NOT_SELECTED,   NOT_SELECTED,     NOT_SELECTED,
#
#                    6                 7
# 0                 6   NOT_SELECTED, 7
# 1         SELECTED,     NOT_SELECTED,
# 2     NOT_SELECTED,     NOT_SELECTED,
# 3         SELECTED,     NOT_SELECTED,
# 4                       NOT_SELECTED,
# 5       SELECTED, 6   NOT_SELECTED, 7
# 6         SELECTED,     NOT_SELECTED,
# 7     NOT_SELECTED,         SELECTED,
# 8     NOT_SELECTED,         SELECTED,
# 9     NOT_SELECTED,     NOT_SELECTED,
# 10    NOT_SELECTED,
# 11  NOT_SELECTED, 6   NOT_SELECTED, 7
# 12        SELECTED,     NOT_SELECTED,
