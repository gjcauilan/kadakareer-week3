# %%
import boto3
import pandas as pd
from trp import Document

bucketname = "kadakareer1"
formname = "MER_Annex D_seabed 2.jpg"

module = boto3.client('textract')

response = module.analyze_document(
    Document={
        'S3Object': {
            'Bucket': bucketname,
            'Name': formname
        }
    },
    FeatureTypes=["FORMS"]
)
doc = Document(response)

keys = []
values = []

for page in doc.pages:
    for field in page.form.fields:
        keys.append(field.key.text if field.key else "")
        values.append(field.value.text if field.value else "")

data = {'Key': keys, 'Value': values}
df = pd.DataFrame(data)

print('-----Amazon Textract has detected as follows-----')
print(df)

df.to_csv('Week 3 - 2.csv', index=False)
# Out:
# -----Amazon Textract has detected as follows-----
#                                                   Key           Value
# 0                              For Further Evaluation    NOT_SELECTED
# 1                           WITH SIGNIFICANT FINDINGS    NOT_SELECTED
# 2                           WITH SIGNIFICANT FINDINGS    NOT_SELECTED
# 3                                              Normal        SELECTED
# 4                                              Normal        SELECTED
# 5                                            Reactive    NOT_SELECTED
# 6                           WITH SIGNIFICANT FINDINGS    NOT_SELECTED
# 7                                            Reactive    NOT_SELECTED
# 8                                                 YES    NOT_SELECTED
# 9                                        Non-Reactive        SELECTED
# 10                                             PASSED        SELECTED
# 11                                       Non-Reactive        SELECTED
# 12                                      With Findings    NOT_SELECTED
# 13                                               DATE       25/9/2023
# 14                            I BLOOD TYPE (Specify):              At
# 15                     MEDICAL EXAMINATION REPORT NO:      5678901234
# 16                                           Reactive    NOT_SELECTED
# 17                                             Normal        SELECTED
# 18                                                 NO        SELECTED
# 19                                      With Findings    NOT_SELECTED
# 20                                      With Findings    NOT_SELECTED
# 21                                             Normal        SELECTED
# 22                                      With Findings    NOT_SELECTED
# 23                              WITHOUT RESTRICTIONS:        SELECTED
# 24                                             PASSED        SELECTED
# 25                                       Non-Reactive        SELECTED
# 26                                             Normal        SELECTED
# 27                                             PASSED        SELECTED
# 28                     NAME AND SIGNATURE OF SEAFARER  JAMES DEVLIN A
# 29                                           ADDRESS:      PASIG CITY
# 30                                             Normal        SELECTED
# 31                                    LICENSE NUMBER:      4567890123
# 32                                      With Findings    NOT_SELECTED
# 33  IV. SUMMARY. Place a check mark () in the appr...    NOT_SELECTED
# 34                                              MONTH               9
# 35                          NOT FIT FOR LOOK-OUT DUTY    NOT_SELECTED
# 36  III. RESULTS OF ANCILLARY EXAMINATIONS. Place ...    NOT_SELECTED
# 37                                               YEAR            2024
# 38  NAME AND SIGNATURE OF EXAMINING/AUTHORIZED PHY...      CLARK TONG
# 39                                                DAY              25
# 40                                              MONTH               9
# 41                                               YEAR            2023
# 42                              FIT FOR LOOK-OUT DUTY        SELECTED
# 43                                     OTHER SERVICES    NOT_SELECTED
# 44                                                DAY              25
# 45  REMARKS/SPECIAL NEEDS (Sspecify e.g. with medi...
# 46  Describe restrictions** (refer to standard res...
# 47  V. ASSESSMENT OF FITNESS FOR SERVICE AT SEA. P...    NOT_SELECTED
# 48                                 WITH RESTRICTIONS:    NOT_SELECTED
# 49                                   CATERING SERVICE    NOT_SELECTED
# 50  I hereby authorize the release of all my medic...       SHIP INC.
# 51                                     ENGINE SERVICE        SELECTED
# 52                                       DECK SERVICE    NOT_SELECTED
# 53                                      Mouth, Throat        SELECTED
