# %%
import boto3
import pandas as pd
from trp import Document

bucketname = "kadakareer1"
formname = "Annex_D_Med_Cert_seabased.jpg"

module = boto3.client('textract')

response = module.analyze_document(
    Document={
        'S3Object': {
            'Bucket': bucketname,
            'Name': formname
        }
    },
    FeatureTypes=["FORMS"]
)
doc = Document(response)

keys = []
values = []

for page in doc.pages:
    for field in page.form.fields:
        keys.append(field.key.text if field.key else "")
        values.append(field.value.text if field.value else "")

data = {'Key': keys, 'Value': values}
df = pd.DataFrame(data)

print('-----Amazon Textract has detected as follows-----')
print(df)

df.to_csv('Week 3 - 9.csv', index=False)
# Out:
# -----Amazon Textract has detected as follows-----
#                                                   Key  \
# 0                                        MIDDLE NAME:
# 1                                                  NO
# 2                                   GIVEN/FIRST NAME:
# 3                                  SURNAME/LAST NAME:
# 4                                        NATIONALITY:
# 5                                           RELIGION:
# 6                               SEAMAN'S BOOK NUMBER.
# 7                                            COMPANY:
# 8                                                  NO
# 9                                     PLACE OF BIRTH:
# 10                                                YES
# 11                                   PASSPORT NUMBER:
# 12                                                 NO
# 13                                                 NO
# 14                                               AGE:
# 15                                                 NO
# 16                                                 NO
# 17                                                YES
# 18                                                 NO
# 19                                            MARRIED
# 20                                                YES
# 21                                                YES
# 22                                             SINGLE
# 23                                             ENGINE
# 24                                                YES
# 25                                             FEMALE
# 26                                                 NO
# 27                                                YES
# 28                                                YES
# 29                                              DATE:
# 30                                                YES
# 31                                           CATERING
# 32                  DATE OF ISSUANCE:DAY/ MONTH/ YEAR
# 33                                     CONTACT LENSES
# 34                                         SPECTACLES
# 35                                            ADDRESS
# 36                                               DECK
# 37                                               MALE
# 38                  PHYSICIAN'S CERTIFYING AUTHORITY.
# 39                                        APPROVED BY
# 40                        PHYSICIAN'S LICENSE NUMBER:
# 41                                                DAY
# 42                              RESULT: FIT FOR DUTY.
# 43                         NAME OF ISSUING AUTHORITY.
# 44                     SEAFARER'S NAME AND SIGNATURE:
# 45                        DATE OF EXPIRATION: MONTH/Y
# 46                                           ADDRESS.
# 47  THIS IS TO CERTIFY THAT A MEDICALAND PHYSICAL ...
# 48                                              MONTH
# 49  NAME AND SIGNATURE OF EXAMINING/AUTHORIZED DAT...
# 50                                            SPECIFY
# 51                                            '93YEAR
# 52                                             OTHERS
# 53  Date of last colour vision test: (Day/ Month/ ...
# 54                                     UNFIT FOR DUTY
# 55                                           A.O. No.
# 56                                              ANNEX
#
#                                             Value
# 0                                          ISAACS
# 1                                    NOT_SELECTED
# 2                                           JAMES
# 3                                         DEVL IN
# 4                                        FILIPINO
# 5                                            NONE
# 6                                      2345678901
# 7                                       SHIP INC.
# 8                                    NOT_SELECTED
# 9                                          MANILA
# 10                                       SELECTED
# 11                                     1234567890
# 12                                   NOT_SELECTED
# 13                                   NOT_SELECTED
# 14                                             30
# 15                                   NOT_SELECTED
# 16                                   NOT_SELECTED
# 17                                       SELECTED
# 18                                   NOT_SELECTED
# 19                                   NOT_SELECTED
# 20                                       SELECTED
# 21                                       SELECTED
# 22                                       SELECTED
# 23                                       SELECTED
# 24                                       SELECTED
# 25                                   NOT_SELECTED
# 26                                       SELECTED
# 27                                   NOT_SELECTED
# 28                                       SELECTED
# 29                                      25/9/2023
# 30                                       SELECTED
# 31                                   NOT_SELECTED
# 32                                   25 / 9/ 2023
# 33                                   NOT_SELECTED
# 34                                   NOT_SELECTED
# 35  7 RD. 22, PROJECT 8, QUEZON CITY, PHILIPPINES
# 36                                   NOT_SELECTED
# 37                                       SELECTED
# 38                                     3456789102
# 39                                  JOHN SMITH or
# 40                                     4567891023
# 41                                              2
# 42                                       SELECTED
# 43                          DEPARTMENT of THE SEA
# 44                                JAMES DEVLIN 9v
# 45                                      25/9/2024
# 46                                     PASIG CITY
# 47                                   JAMES DEVLIN
# 48                                             10
# 49                                   2 / 9 / 2023
# 50
# 51
# 52                                   NOT_SELECTED
# 53                                  2 / 10 / 2022
# 54                                   NOT_SELECTED
# 55                                      2013-0006
# 56                                              D
